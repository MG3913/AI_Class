#        list([1, 2, 2, 69, 72, 2, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 2, 2, 45, 58, 2, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 2, 51, 575, 32, 61, 369, 71, 66, 770, 12, 2, 75, 100, 2, 8, 4, 105, 37, 69, 147, 712, 75, 2, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 2, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 2, 112, 2, 11, 2, 121, 25, 70, 2, 4, 719, 2, 13, 18, 31, 62, 40, 8, 2, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 2, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23]),
#        list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 2, 270, 2, 5, 2, 2, 732, 2, 101, 405, 39, 14, 2, 4, 2, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 2, 2, 9, 24, 6, 78, 2, 17, 2, 2, 21, 27, 2, 2, 5, 2, 2, 92, 2, 4, 2, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 2, 2, 9, 6, 66, 78, 2, 4, 631, 2, 5, 2, 272, 191, 2, 6, 2, 8, 2, 2, 2, 544, 5, 383, 2, 848, 2, 2, 497, 2, 8, 2, 2, 2, 21, 60, 27, 239, 9, 43, 2, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 2, 72, 7, 51, 6, 2, 22, 4, 204, 131, 9])],
#       dtype=object)

# %%
#원-핫 인코딩으로 변환하는 함수 
def one_hot_sequences(sequences, dimension=1000):
    results = numpy.zeros((len(sequences), dimension))
    for i, word_index in enumerate(sequences):
            results[i, word_index] = 1.
    return results

train_data = one_hot_sequences(train_data)
test_data = one_hot_sequences(test_data)

# %%
# 신경망 모델 구축
from keras.layers import Input, Dense, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping

inputs = Input(shape=(1000,))
x = Dense(16, activation="relu")(inputs)
a = Dropout(0.5)(x)
y = Dense(16, activation="relu")(a)
b = Dropout(0.5)(y)
prediction = Dense(1, activation="sigmoid")(b)

model = Model(inputs=inputs, outputs=prediction)
model.compile(loss='binary_crossentropy', optimizer='adam', 
              metrics=['accuracy'])
early_stopping = EarlyStopping()

# %%
#신경망 훈련, 검증 데이터 전달
history = model.fit(train_data,
                   train_labels,
                   epochs=20,
                   batch_size=512,
                   validation_data=(test_data, test_labels),
                   verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6749 - accuracy: 0.5612 - val_loss: 0.6062 - val_accuracy: 0.7586 - 1s/epoch - 22ms/step
# Epoch 2/20
# 49/49 - 0s - loss: 0.5719 - accuracy: 0.6995 - val_loss: 0.4536 - val_accuracy: 0.8241 - 244ms/epoch - 5ms/step
# Epoch 3/20
# 49/49 - 0s - loss: 0.4786 - accuracy: 0.7736 - val_loss: 0.3812 - val_accuracy: 0.8440 - 279ms/epoch - 6ms/step
# Epoch 4/20
# 49/49 - 0s - loss: 0.4341 - accuracy: 0.8101 - val_loss: 0.3493 - val_accuracy: 0.8510 - 271ms/epoch - 6ms/step
# Epoch 5/20
# 49/49 - 0s - loss: 0.3971 - accuracy: 0.8295 - val_loss: 0.3316 - val_accuracy: 0.8561 - 270ms/epoch - 6ms/step
# Epoch 6/20
# 49/49 - 0s - loss: 0.3767 - accuracy: 0.8443 - val_loss: 0.3257 - val_accuracy: 0.8578 - 268ms/epoch - 5ms/step
# Epoch 7/20
# 49/49 - 0s - loss: 0.3627 - accuracy: 0.8523 - val_loss: 0.3232 - val_accuracy: 0.8599 - 276ms/epoch - 6ms/step
# Epoch 8/20
# 49/49 - 0s - loss: 0.3517 - accuracy: 0.8600 - val_loss: 0.3229 - val_accuracy: 0.8592 - 272ms/epoch - 6ms/step
# Epoch 9/20
# 49/49 - 0s - loss: 0.3443 - accuracy: 0.8642 - val_loss: 0.3220 - val_accuracy: 0.8599 - 266ms/epoch - 5ms/step
# Epoch 10/20
# 49/49 - 0s - loss: 0.3351 - accuracy: 0.8659 - val_loss: 0.3229 - val_accuracy: 0.8608 - 252ms/epoch - 5ms/step
# Epoch 11/20
# 49/49 - 0s - loss: 0.3249 - accuracy: 0.8704 - val_loss: 0.3239 - val_accuracy: 0.8598 - 269ms/epoch - 5ms/step
# Epoch 12/20
# 49/49 - 0s - loss: 0.3158 - accuracy: 0.8722 - val_loss: 0.3271 - val_accuracy: 0.8596 - 263ms/epoch - 5ms/step
# Epoch 13/20
# 49/49 - 0s - loss: 0.3158 - accuracy: 0.8748 - val_loss: 0.3283 - val_accuracy: 0.8597 - 262ms/epoch - 5ms/step
# Epoch 14/20
# 49/49 - 0s - loss: 0.3112 - accuracy: 0.8752 - val_loss: 0.3313 - val_accuracy: 0.8590 - 269ms/epoch - 5ms/step
# Epoch 15/20
# 49/49 - 0s - loss: 0.3009 - accuracy: 0.8810 - val_loss: 0.3320 - val_accuracy: 0.8590 - 268ms/epoch - 5ms/step
# Epoch 16/20
# 49/49 - 0s - loss: 0.3001 - accuracy: 0.8797 - val_loss: 0.3327 - val_accuracy: 0.8587 - 263ms/epoch - 5ms/step
# Epoch 17/20
# 49/49 - 0s - loss: 0.2961 - accuracy: 0.8828 - val_loss: 0.3337 - val_accuracy: 0.8572 - 261ms/epoch - 5ms/step
# Epoch 18/20
# 49/49 - 0s - loss: 0.2939 - accuracy: 0.8823 - val_loss: 0.3398 - val_accuracy: 0.8577 - 270ms/epoch - 6ms/step
# Epoch 19/20
# 49/49 - 0s - loss: 0.2935 - accuracy: 0.8827 - val_loss: 0.3408 - val_accuracy: 0.8568 - 259ms/epoch - 5ms/step
# Epoch 20/20
# 49/49 - 0s - loss: 0.2878 - accuracy: 0.8851 - val_loss: 0.3401 - val_accuracy: 0.8554 - 270ms/epoch - 6ms/step

# %%
#훈련 데이터의 손실값과 검증 데이터의 손실값을 그래프에 출력
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc = history_dict['accuracy']
epochs = range(1, len(acc) + 1)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Plot')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train error', 'val error'], loc='upper left')
plt.show()
